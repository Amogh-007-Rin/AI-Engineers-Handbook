# %% [markdown]
# # Python contract lab
# Implement and test a small numerical boundary.

# %%
def safe_mean(values):
    if not values:
        raise ValueError('values must be non-empty')
    if not all(isinstance(v, (int, float)) for v in values):
        raise TypeError('values must be numeric')
    return sum(values) / len(values)

# %%
assert safe_mean([1, 2, 3]) == 2
try:
    safe_mean([])
except ValueError:
    pass
else:
    raise AssertionError('empty input must fail')

# %% [markdown]
# ## Reflection
# State the input contract, complexity, one alternative, and two more failures.
